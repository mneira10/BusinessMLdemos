# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#               date  store  item  sales
# 0       2013-01-01      1     1     13
# 1       2013-01-02      1     1     11
# 2       2013-01-03      1     1     14
# 3       2013-01-04      1     1     13
# 4       2013-01-05      1     1     10
# ...            ...    ...   ...    ...
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82
#
# [913000 rows x 4 columns]

# %%
subTrain = train[train.store==1]

# %%
fig = go.Figure()

for item in subTrain.item.unique():
    temp = subTrain[subTrain.item==item]
    plt.scatter(temp.date,temp.sales)
    fig.add_trace(go.Scatter(x=temp.date, y=temp.sales,
                    mode='lines',
                    name='Product {}'.format(item)))
    break

fig.show()

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

table = ff.create_table(train.iloc[:10])
py.offline.iplot(table, filename='jupyter-table1')

# %%
# fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
# fig.show()


# # Create traces
# fig = go.Figure()
# fig.add_trace()
# # fig.add_trace(go.Scatter(x=random_x, y=random_y1,
# #                     mode='lines+markers',
# #                     name='lines+markers'))
# # fig.add_trace(go.Scatter(x=random_x, y=random_y2,
# #                     mode='markers', name='markers'))

# fig.show()

data = [go.Scatter(x=subTrain[subTrain.item==1].date, y=subTrain[subTrain.item==1].sales,
                    mode='lines',
                    name='lines')]
py.offline.iplot(data)
